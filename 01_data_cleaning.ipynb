# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/praavars/FSFM/Penalty Kick/data/real_data.xlsx")
df.head()
# Out:
#   Unnamed: 0   Country  player_id player_name Kicker_Foot Kicker_Side  \
# 0      24/25  Portugal        1.0     Galeno            R           L
# 1      24/25  Portugal        2.0      Namaso           R           L
# 2      24/25  Portugal        3.0      Safira           R           R
# 3      24/25  Portugal        4.0    Reisinho           L           L
# 4      24/25  Portugal        1.0     Galeno            R           L
#
#   Goalie_Side  Outcome    goalkeer_name  goalkeeper_id  ...  Unnamed: 16  \
# 0           L      1.0           Andrew            1.0  ...          NaN
# 1           R      1.0           Andrew            1.0  ...          NaN
# 2           L      1.0    Dani Figueira            2.0  ...          NaN
# 3           R      1.0  Ricardo Batista            3.0  ...          NaN
# 4           R      1.0  Gabriel Batista            4.0  ...          NaN
#
#    Unnamed: 17  Unnamed: 18 Unnamed: 19  Unnamed: 20  player_name.1  \
# ...

# %%
df.shape
# Out:
# (482, 26)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'player_id', 'player_name', 'Kicker_Foot',
#        'Kicker_Side', 'Goalie_Side', 'Outcome', 'goalkeer_name',
#        'goalkeeper_id', 'Home_Goals', 'Away_Goals', 'Minute', 'Team_Type',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'player_name.1',
#        'player_id.1', 'Unnamed: 23', 'goalkeer_name.1', 'goalkeeper_id.1'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       482 non-null    object
#  1   Country          482 non-null    object
#  2   player_id        475 non-null    float64
#  3   player_name      482 non-null    object
#  4   Kicker_Foot      482 non-null    object
#  5   Kicker_Side      482 non-null    object
#  6   Goalie_Side      482 non-null    object
#  7   Outcome          482 non-null    float64
#  8   goalkeer_name    482 non-null    object
#  9   goalkeeper_id    481 non-null    float64
#  10  Home_Goals       482 non-null    int64
#  11  Away_Goals       482 non-null    int64
#  12  Minute           482 non-null    int64
#  13  Team_Type        482 non-null    object
#  14  Unnamed: 14      0 non-null      float64
#  15  Unnamed: 15      0 non-null      float64
# ...

# %%
df.isnull().sum() ##Missing values in each column
# Out:
# Unnamed: 0           0
# Country              0
# player_id            7
# player_name          0
# Kicker_Foot          0
# Kicker_Side          0
# Goalie_Side          0
# Outcome              0
# goalkeer_name        0
# goalkeeper_id        1
# Home_Goals           0
# Away_Goals           0
# Minute               0
# Team_Type            0
# Unnamed: 14        482
# Unnamed: 15        482
# Unnamed: 16        482
# Unnamed: 17        482
# Unnamed: 18        482
# Unnamed: 19        482
# Unnamed: 20        482
# player_name.1      304
# player_id.1        304
# Unnamed: 23        482
# goalkeer_name.1    373
# goalkeeper_id.1    373
# dtype: int64

# %%
df.nunique() ##Unique values in each column
# Out:
# Unnamed: 0           4
# Country              4
# player_id          178
# player_name        180
# Kicker_Foot          2
# Kicker_Side          3
# Goalie_Side          3
# Outcome              9
# goalkeer_name      110
# goalkeeper_id      109
# Home_Goals           6
# Away_Goals           5
# Minute              87
# Team_Type            2
# Unnamed: 14          0
# Unnamed: 15          0
# Unnamed: 16          0
# Unnamed: 17          0
# Unnamed: 18          0
# Unnamed: 19          0
# Unnamed: 20          0
# player_name.1      178
# player_id.1        178
# Unnamed: 23          0
# goalkeer_name.1    109
# goalkeeper_id.1    109
# dtype: int64

# %%
df['Kicker_Side'].value_counts()
# Out:
# Kicker_Side
# L    229
# R    199
# C     54
# Name: count, dtype: int64

# %%
df['Kicker_Foot'].value_counts()
# Out:
# Kicker_Foot
# R    323
# L    159
# Name: count, dtype: int64

# %%
df['Goalie_Side'].value_counts()
# Out:
# Goalie_Side
# L    252
# R    218
# C     12
# Name: count, dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 1.000000    401
# 0.000000     73
# 0.041667      2
# 0.000694      1
# 0.125694      1
# 0.042361      1
# 0.001389      1
# 0.126389      1
# 0.083333      1
# Name: count, dtype: int64

# %%
df['Unnamed: 0'].value_counts()
# Out:
# Unnamed: 0
# 20/21    150
# 24/25    112
# 23/24    111
# 22/23    109
# Name: count, dtype: int64

# %%
df[~df['Outcome'].isin([0, 1])] ##Shows value for which Outcome is neither 0 nor 1
# Out:
#     Unnamed: 0 Country  player_id        player_name Kicker_Foot Kicker_Side  \
# 314      22/23   Italy      140.0     Andrea Belotti           R           C
# 316      22/23   Italy       96.0   Teun Koopmeiners           L           R
# 318      22/23   Italy      127.0  Abdelhamid Sabiri           R           R
# 319      22/23   Italy      120.0       Luis Alberto           R           L
# 321      22/23   Italy       94.0     Dušan Vlahović           L           L
# 322      22/23   Italy      141.0    Bryan Cristante           R           R
# 323      22/23   Italy      142.0    Roberto Pereyra           R           L
# 324      22/23   Italy      143.0    Arkadiusz Milik           L           L
#
#     Goalie_Side   Outcome           goalkeer_name  goalkeeper_id  ...  \
# 314           R  0.000694  Vanja Milinkovič-Savič           67.0  ...
# 316           R  0.125694         Guillermo Ochoa           18.0  ...
# ...

# %%
df.loc[
    ~df['Outcome'].isin([0, 1]),
    [
        'Unnamed: 0',
        'Country',
        'player_name',
        'Kicker_Foot',
        'Kicker_Side',
        'Goalie_Side',
        'Outcome',
        'goalkeer_name',
        'Home_Goals',
        'Away_Goals',
        'Minute',
        'Team_Type'
    ]
]
# Out:
#     Unnamed: 0 Country        player_name Kicker_Foot Kicker_Side Goalie_Side  \
# 314      22/23   Italy     Andrea Belotti           R           C           R
# 316      22/23   Italy   Teun Koopmeiners           L           R           R
# 318      22/23   Italy  Abdelhamid Sabiri           R           R           R
# 319      22/23   Italy       Luis Alberto           R           L           L
# 321      22/23   Italy     Dušan Vlahović           L           L           R
# 322      22/23   Italy    Bryan Cristante           R           R           L
# 323      22/23   Italy    Roberto Pereyra           R           L           L
# 324      22/23   Italy    Arkadiusz Milik           L           L           L
#
#       Outcome           goalkeer_name  Home_Goals  Away_Goals  Minute  \
# 314  0.000694  Vanja Milinkovič-Savič           0           1      90
# 316  0.125694         Guillermo Ochoa           3           1      38
# ...

# %%
df.rename(columns={'Unnamed: 0': 'Season', 'goalkeer_name': "goalkeeper_name"}, inplace=True) ##Renaming columns

# %%
df_clean = df[df['Outcome'].isin([0, 1])].copy()
df_clean['Outcome'].value_counts()
# Out:
# Outcome
# 1.0    401
# 0.0     73
# Name: count, dtype: int64

# %%
df_clean.shape
# Out:
# (474, 26)

# %%
df_clean.isnull().sum()
# Out:
# Season               0
# Country              0
# player_id            7
# player_name          0
# Kicker_Foot          0
# Kicker_Side          0
# Goalie_Side          0
# Outcome              0
# goalkeeper_name      0
# goalkeeper_id        1
# Home_Goals           0
# Away_Goals           0
# Minute               0
# Team_Type            0
# Unnamed: 14        474
# Unnamed: 15        474
# Unnamed: 16        474
# Unnamed: 17        474
# Unnamed: 18        474
# Unnamed: 19        474
# Unnamed: 20        474
# player_name.1      296
# player_id.1        296
# Unnamed: 23        474
# goalkeer_name.1    365
# goalkeeper_id.1    365
# dtype: int64

# %%
df_clean[['player_name.1', 'player_id.1', 'goalkeer_name.1', 'goalkeeper_id.1', 
          'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 23']].head(20)
# Out:
#      player_name.1  player_id.1  goalkeer_name.1  goalkeeper_id.1  \
# 0          Galeno           1.0           Andrew              1.0
# 1           Namaso          2.0    Dani Figueira              2.0
# 2           Safira          3.0  Ricardo Batista              3.0
# 3         Reisinho          4.0  Gabriel Batista              4.0
# 4             Alan          5.0       Nico Mantl              5.0
# 5         Fujimoto          6.0            Simao              6.0
# 6          Clayton          7.0            Kewin              7.0
# 7      M. Leonardo          8.0            Velho              8.0
# 8   Ángel Di María          9.0     Lucas França              9.0
# 9         Cassiano         10.0           Varela             10.0
# 10     G. Assunçao         11.0   Bruno Brigiido             11.0
# 11        T. Silva         12.0           Robles             12.0
# 12        R. Pinho         13.0          Matheus             13.0
# ...

# %%
columns_to_drop = [
    'Unnamed: 14',
    'Unnamed: 15',
    'Unnamed: 16',
    'Unnamed: 17',
    'Unnamed: 18',
    'Unnamed: 19',
    'Unnamed: 20',
    'Unnamed: 23',
    'player_name.1',
    'player_id.1',
    'goalkeer_name.1',
    'goalkeeper_id.1'
]

df_clean = df_clean.drop(columns=columns_to_drop)

# %%
df_clean.shape
# Out:
# (474, 14)

# %%
df_clean.columns
# Out:
# Index(['Season', 'Country', 'player_id', 'player_name', 'Kicker_Foot',
#        'Kicker_Side', 'Goalie_Side', 'Outcome', 'goalkeeper_name',
#        'goalkeeper_id', 'Home_Goals', 'Away_Goals', 'Minute', 'Team_Type'],
#       dtype='object')

# %%
df_clean.isnull().sum()
# Out:
# Season             0
# Country            0
# player_id          7
# player_name        0
# Kicker_Foot        0
# Kicker_Side        0
# Goalie_Side        0
# Outcome            0
# goalkeeper_name    0
# goalkeeper_id      1
# Home_Goals         0
# Away_Goals         0
# Minute             0
# Team_Type          0
# dtype: int64

# %%
df_clean = df_clean.drop(columns=["player_id", "goalkeeper_id"])

# %%
df_clean.isnull().sum()
# Out:
# Season             0
# Country            0
# player_name        0
# Kicker_Foot        0
# Kicker_Side        0
# Goalie_Side        0
# Outcome            0
# goalkeeper_name    0
# Home_Goals         0
# Away_Goals         0
# Minute             0
# Team_Type          0
# dtype: int64

# %%
columns_to_check = ["Season", "Country", "Kicker_Foot", "Kicker_Side", "Goalie_Side", "Outcome"]
for items in columns_to_check:
    print (f"Column name: {items}")
    print("-" * 30)
    print (df_clean[items].value_counts())
# Out:
# Column name: Season
# ------------------------------
# Season
# 20/21    150
# 24/25    112
# 23/24    111
# 22/23    101
# Name: count, dtype: int64
# Column name: Country
# ------------------------------
# Country
# Italy       166
# Portugal    116
# England     107
# Italy        85
# Name: count, dtype: int64
# Column name: Kicker_Foot
# ------------------------------
# Kicker_Foot
# R    318
# L    156
# Name: count, dtype: int64
# Column name: Kicker_Side
# ------------------------------
# Kicker_Side
# L    225
# R    196
# C     53
# Name: count, dtype: int64
# Column name: Goalie_Side
# ------------------------------
# Goalie_Side
# L    248
# R    214
# C     12
# Name: count, dtype: int64
# Column name: Outcome
# ------------------------------
# Outcome
# 1.0    401
# 0.0     73
# Name: count, dtype: int64

# %%
for country in df_clean["Country"].unique():
    print(repr(country))
# Out:
# 'Portugal'
# 'England'
# 'Italy '
# 'Italy'

# %%
df_clean["Country"] = df_clean["Country"].str.strip()
df_clean["Country"].value_counts()
# Out:
# Country
# Italy       251
# Portugal    116
# England     107
# Name: count, dtype: int64

# %%
columns_to_check = ["Season", "Country", "player_name", "Kicker_Foot", "Kicker_Side", "Goalie_Side", "Outcome", "goalkeeper_name", "Home_Goals", "Away_Goals", "Minute", "Team_Type"]
for items in columns_to_check:
    print (f"Column name: {items}")
    print("-" * 30)
    print (df_clean[items].value_counts())
# Out:
# Column name: Season
# ------------------------------
# Season
# 20/21    150
# 24/25    112
# 23/24    111
# 22/23    101
# Name: count, dtype: int64
# Column name: Country
# ------------------------------
# Country
# Italy       251
# Portugal    116
# England     107
# Name: count, dtype: int64
# Column name: player_name
# ------------------------------
# player_name
# Domenico Berardi    16
# Franck Kessié       13
# Ciro Immobile       13
# Gyokeres            12
# João Pedro          10
#                     ..
# Cunha                1
# Madueke              1
# Olise                1
# Morgan G.            1
# Cristo               1
# Name: count, Length: 178, dtype: int64
# Column name: Kicker_Foot
# ------------------------------
# Kicker_Foot
# R    318
# L    156
# Name: count, dtype: int64
# Column name: Kicker_Side
# ------------------------------
# Kicker_Side
# L    225
# R    196
# C     53
# Name: count, dtype: int64
# Column name: Goalie_Side
# ...

# %%
df_clean.to_csv("data/cleaned_penalty_data.csv", index=False)
